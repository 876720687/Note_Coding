# %%
60 25(次数一定要交) 10 5
1、判断 2*20 每小题若不作答可得一分
2、填空 2*10
3、简答 3*6 
4、程序填空 6*1
5、写代码

彩云上有复习题纲

# %%
参考文档
[
    https://blog.csdn.net/fengdu78/article/details/107754712
    https://www.cnblogs.com/presleyren/p/14372001.html
    https://www.heywhale.com/mw/project/5faf844d7d1e6d0030d75665
]

# %% [markdown]
# ## 柱状图的堆叠

# %%
from pyecharts.charts import *
from pyecharts import options as opts
from pyecharts.faker import Faker


def bar_stack():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='500px',
                                      height='300px'))
    bar.add_xaxis(Faker.choose())
    # stack值一样的系列会堆叠在一起
    bar.add_yaxis('A', Faker.values(), stack='stack1')
    bar.add_yaxis('B', Faker.values(), stack='stack1')
    bar.add_yaxis('C', Faker.values(), stack='stack2')
    return bar



chart = bar_stack()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1c2497fd8cd748b5b58a87394df3627a" style="width:500px; height:300px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1c2497fd8cd748b5b58a87394df3627a = echarts.init(
#                     document.getElementById('1c2497fd8cd748b5b58a87394df3627a'), 'light', {renderer: 'canvas'});
#                 var option_1c2497fd8cd748b5b58a87394df3627a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "A",
#             "legendHoverLink": true,
#             "data": [
# ...

# %% [markdown]
# ## 这个里面的数据量貌似很大？结构呢？

# %%
bar = (Bar()
       .add_xaxis(Faker.choose())
       #.add_yaxis('drink',Faker.values())
       .add_yaxis('',Faker.values())
)

bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="372c4e910e9e478f9c0292819abbe276" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_372c4e910e9e478f9c0292819abbe276 = echarts.init(
#                     document.getElementById('372c4e910e9e478f9c0292819abbe276'), 'white', {renderer: 'canvas'});
#                 var option_372c4e910e9e478f9c0292819abbe276 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# 虚假数据
x_data = ['Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Vivo', 'Meizu']
y_data = [123, 153, 89, 107, 98, 23]

line = (Line()
       .add_xaxis(x_data)
       .add_yaxis('', y_data)
       .set_global_opts(title_opts = opts.TitleOpts(title = 'line_data',subtitle='second')
                         #,toolbox_opts = opts.ToolboxOpts()
                         #,init_opts=opts.InitOpts(theme='light',width='500px',height='300px')
                         ,legend_opts=opts.LegendOpts(pos_left=1)
                        )
      )

line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9c9e8658396b4cf7914ad492972ab274" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9c9e8658396b4cf7914ad492972ab274 = echarts.init(
#                     document.getElementById('9c9e8658396b4cf7914ad492972ab274'), 'white', {renderer: 'canvas'});
#                 var option_9c9e8658396b4cf7914ad492972ab274 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ## 5-2双Y轴显示

# %%
from pyecharts.charts import *
from pyecharts import options as opts
import random

x_data = ['香蕉', '梨子', '水蜜桃', '核桃', '西瓜', '苹果']
y_data_1 = [random.randint(10, 50) for _ in range(len(x_data))]
y_data_2 = [random.randint(100, 500) for _ in range(len(x_data))]

def bar_line_combine_with_two_axis():
    bar = Bar(init_opts=opts.InitOpts(theme='light',
                                      width='500px',
                                      height='300px'))
    bar.add_xaxis(x_data)
    # 添加一个Y轴
    bar.extend_axis(yaxis=opts.AxisOpts())
    bar.add_yaxis('左边Y轴', y_data_1, yaxis_index=0)

    line = Line(init_opts=opts.InitOpts(theme='light',
                                        width='500px',
                                        height='300px'))
    line.add_xaxis(x_data)
    # 将line数据通过yaxis_index指向后添加的Y轴
    line.add_yaxis('右边Y轴', y_data_2, yaxis_index=1)

    bar.overlap(line)
    return bar


chart = bar_line_combine_with_two_axis()
chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="61a987868a8f471ebf5220054c187a9b" style="width:500px; height:300px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_61a987868a8f471ebf5220054c187a9b = echarts.init(
#                     document.getElementById('61a987868a8f471ebf5220054c187a9b'), 'light', {renderer: 'canvas'});
#                 var option_61a987868a8f471ebf5220054c187a9b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5de6\u8fb9Y\u8f74",
#             "yAxisIndex": 0,
# ...

# %% [markdown]
# ## 6-1绘制K线图

# %%
参考资料
[
    https://www.jb51.net/article/206589.htm#_lab2_1_2
]

# %%
import pyecharts.options as opts
from pyecharts.charts import Candlestick
 
x_data = ["2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27"]
y_data = [[20, 30, 10, 35], [40, 35, 30, 55], [33, 38, 33, 40], [40, 40, 32, 42]]
 
(
 Candlestick(init_opts=opts.InitOpts(width="1200px", height="600px"))
 .add_xaxis(xaxis_data=x_data)
 .add_yaxis(series_name="", y_axis=y_data)
 .set_series_opts()
 .set_global_opts(
  yaxis_opts=opts.AxisOpts(
   splitline_opts=opts.SplitLineOpts(
    is_show=True, linestyle_opts=opts.LineStyleOpts(width=1)
   )
  )
 )
 .render("简单K线图.html")
)
# Out:
# 'E:\\CODE\\ProgrammingProgect\\pythoncoding\\简单K线图.html'

# %% [markdown]
# ## 6-2随机日历图

# %%
y_data_1 = [random.randint(10, 50) for _ in range(len(x_data))]

# %% [markdown]
# ## work7-1雷达图

# %% [markdown]
# ###### 对于语文、数学、英语、科学、社会5门课程，张大伟和李小荷的成绩分别为[81, 87，65, 78, 73]和[92, 76, 82, 63, 88]。请将2人的5门成绩利用pyecharts绘制出雷达图。要求可视化元素尽量齐全 、完善。

# %%
data = [
    [81, 87, 65, 78, 73],
    [92, 76, 82, 63, 88]
]


radar = (Radar()
         .add_schema(schema=[
             opts.RadarIndicatorItem(name="语文", max_=150),
             opts.RadarIndicatorItem(name="数学", max_=150),
             opts.RadarIndicatorItem(name="英语", max_=150),
             opts.RadarIndicatorItem(name="科学", max_=300),
             opts.RadarIndicatorItem(name="社会", max_=100)
         ]
)
    .add('', data)
)
radar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dd8f502227e94c9d91bba8e51928e7f2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dd8f502227e94c9d91bba8e51928e7f2 = echarts.init(
#                     document.getElementById('dd8f502227e94c9d91bba8e51928e7f2'), 'white', {renderer: 'canvas'});
#                 var option_dd8f502227e94c9d91bba8e51928e7f2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %% [markdown]
# ## 7-2

# %%
日历图微信步数那题
[
    https://blog.csdn.net/weixin_41108545/article/details/105894394
]
